# %% [markdown]
# <a href="https://colab.research.google.com/github/ravishukla2226-cmd/SD-0114/blob/main/Day_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
d={"key1":1,"key2":2,"key3":3,"key4":4}
{k:v**2for k , v in d.items()}
# Out:
# <>:2: SyntaxWarning: invalid decimal literal
# <>:2: SyntaxWarning: invalid decimal literal
# /tmp/ipykernel_28564/2219581463.py:2: SyntaxWarning: invalid decimal literal
#   {k:v**2for k , v in d.items()}
# {'key1': 1, 'key2': 4, 'key3': 9, 'key4': 16}

# %%
def test():
  return"this is my very very first function"
print(test())
# Out:
# this is my very very first function

# %%
from re import A
def test3():
  return "sudh", 23,325,56,[1,2,3,4]
  test3()
  a,b,c,d=test3()
  a

# %%
def test5 (a,b,c):
  d= a+b/c
  return d

# %%
test5(10,20,30)
# Out:
# 10.666666666666666

# %%
def test6(a,b):
  return a+b

# %%
test6(56,44)
# Out:
# 100

# %%
 def test7(z,x,c):
   return z+x+c/5

# %%
test7(20,40,90)
# Out:
# 78.0

# %%
test6(("sharad"),("gandu"))
# Out:
# 'sharadgandu'

# %%
def atm():
  balance = 1000  # Initial balance

  while True:
    print("\n--- ATM Menu ---")
    print("1. Check Balance")
    print("2. Deposit")
    print("3. Withdraw")
    print("4. Exit")

    choice = input("Enter your choice: ")
    pin= input("enter your pin")
    if choice == '1':
      print(f"Your current balance is: ${balance}")
    elif choice == '2':
      try:
        amount = float(input("Enter amount to deposit: "))
        if amount > 0:
          balance += amount
          print(f"${amount} deposited successfully. New balance: ${balance}")
        else:
          print("Deposit amount must be positive.")
      except ValueError:
        print("Invalid input. Please enter a number.")
    elif choice == '3':
      try:
        amount = float(input("Enter amount to withdraw: "))
        if amount > 0:
          if amount <= balance:
            balance -= amount
            print(f"${amount} withdrawn successfully. New balance: ${balance}")
          else:
            print("Insufficient balance.")
        else:
          print("Withdrawal amount must be positive.")
      except ValueError:
        print("Invalid input. Please enter a number.")
    elif choice == '4':
      print("Thank you for using the ATM!")
      break
    else:
      print("Invalid choice. Please try again.")
