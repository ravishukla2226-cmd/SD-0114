# %% [markdown]
# <a href="https://colab.research.google.com/github/ravishukla2226-cmd/SD-0114/blob/main/day_02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x= int(input("enter a number"))
temp = x
reverse= 0
while x>0:
  digit = x%10
  reverse = (reverse*10)+digit
  x=x//10
if temp==reverse:
  print("palindrome")
else:
  print("not palindrome")
# Out:
# enter a number121
# palindrome

# %%
l=[5,9,6,7,8,9,2,3,18,19]
sum = 0
for i in l:
  if i%2!=0:
    sum=sum+i
print(sum)
# Out:
# 52

# %%
l= [2,3,3,9,7,11,13,12]
same={}
if i in l
if i in same:
    same[i]+=1
  else:
    same[i]=1
print(same)
# Out:
#   File "<tokenize>", line 5
#     else:
#     ^
# IndentationError: unindent does not match any outer indentation level
